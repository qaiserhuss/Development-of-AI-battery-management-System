# %%
import os
import pandas as pd

# processed_data 폴더의 경로
processed_data_folder = './processed_data(without preprocess)'

# 각 그룹별로 파일을 로드하기 위한 사전(dictionary) 초기화
grouped_dataframes = {}
file_names = {}  # 각 그룹의 파일 이름을 저장하기 위한 사전

# 폴더 내의 서브 폴더 및 파일 순회
for root, dirs, files in os.walk(processed_data_folder):
    for dir in dirs:
        dir_path = os.path.join(root, dir)
        file_list = [f for f in os.listdir(dir_path) if f.endswith('.csv')]
        dataframes = []
        names = []  # 파일 이름을 저장할 리스트
        for file in file_list:
            file_path = os.path.join(dir_path, file)
            df = pd.read_csv(file_path)
            dataframes.append(df)
            names.append(file)  # 파일 이름 추가
        grouped_dataframes[dir] = dataframes
        file_names[dir] = names  # 파일 이름 리스트를 사전에 추가

# %%
file_names
# Out:
# {'2017-05-12': ['processed_FastCharge_000003_CH39_structure.csv',
#   'processed_FastCharge_000003_CH40_structure.csv',
#   'processed_FastCharge_000004_CH1_structure.csv',
#   'processed_FastCharge_000004_CH2_structure.csv',
#   'processed_FastCharge_000004_CH3_structure.csv',
#   'processed_FastCharge_000008_CH47_structure.csv',
#   'processed_FastCharge_000008_CH48_structure.csv',
#   'processed_FastCharge_000013_CH13_structure.csv',
#   'processed_FastCharge_000013_CH14_structure.csv',
#   'processed_FastCharge_000014_CH23_structure.csv',
#   'processed_FastCharge_000014_CH24_structure.csv',
#   'processed_FastCharge_000018_CH18_structure.csv',
#   'processed_FastCharge_000019_CH29_structure.csv',
#   'processed_FastCharge_000019_CH30_structure.csv',
#   'processed_FastCharge_000023_CH37_structure.csv',
#   'processed_FastCharge_000023_CH38_structure.csv',
#   'processed_FastCharge_000025_CH7_structure.csv',
#   'processed_FastCharge_000026_CH5_structure.csv',
#   'processed_FastCharge_000026_CH6_structure.csv',
#   'processed_FastCharge_000028_CH19_structure.csv',
#   'processed_FastCharge_000028_CH20_structure.csv',
#   'processed_FastCharge_000029_CH10_structure.csv',
#   'processed_FastCharge_000029_CH9_structure.csv',
#   'processed_FastCharge_000037_CH21_structure.csv',
#   'processed_FastCharge_000037_CH22_structure.csv',
#   'processed_FastCharge_000039_CH27_structure.csv',
#   'processed_FastCharge_000039_CH28_structure.csv',
#   'processed_FastCharge_000044_CH11_structure.csv',
#   'processed_FastCharge_000044_CH12_structure.csv',
#   'processed_FastCharge_000045_CH1_structure.csv',
#   'processed_FastCharge_000045_CH2_structure.csv',
#   'processed_FastCharge_000045_CH3_structure.csv',
#   'processed_FastCharge_000046_CH31_structure.csv',
#   'processed_FastCharge_000046_CH32_structure.csv',
#   'processed_FastCharge_000048_CH43_structure.csv',
#   'processed_FastCharge_000048_CH44_structure.csv',
#   'processed_FastCharge_000051_CH15_structure.csv',
#   'processed_FastCharge_000051_CH16_structure.csv',
#   'processed_FastCharge_000057_CH35_structure.csv',
#   'processed_FastCharge_000057_CH36_structure.csv',
#   'processed_FastCharge_000058_CH45_structure.csv',
#   'processed_FastCharge_000058_CH46_structure.csv',
#   'processed_FastCharge_000063_CH5_structure.csv',
#   'processed_FastCharge_000063_CH6_structure.csv',
#   'processed_FastCharge_000065_CH33_structure.csv',
#   'processed_FastCharge_000065_CH34_structure.csv',
#   'processed_FastCharge_000066_CH25_structure.csv',
#   'processed_FastCharge_000066_CH26_structure.csv',
#   'processed_FastCharge_000067_CH41_structure.csv',
#   'processed_FastCharge_000067_CH42_structure.csv'],
#  '2017-06-30': ['processed_FastCharge_000000_CH19_structure.csv',
#   'processed_FastCharge_000005_CH18_structure.csv',
#   'processed_FastCharge_000009_CH4_structure.csv',
#   'processed_FastCharge_000009_CH7_structure.csv',
#   'processed_FastCharge_000009_CH8_structure.csv',
#   'processed_FastCharge_000010_CH44_structure.csv',
#   'processed_FastCharge_000011_CH26_structure.csv',
#   'processed_FastCharge_000016_CH17_structure.csv',
#   'processed_FastCharge_000020_CH23_structure.csv',
#   'processed_FastCharge_000021_CH28_structure.csv',
#   'processed_FastCharge_000022_CH24_structure.csv',
#   'processed_FastCharge_000024_CH45_structure.csv',
#   'processed_FastCharge_000027_CH31_structure.csv',
#   'processed_FastCharge_000030_CH30_structure.csv',
#   'processed_FastCharge_000031_CH9_structure.csv',
#   'processed_FastCharge_000032_CH22_structure.csv',
#   'processed_FastCharge_000033_CH14_structure.csv',
#   'processed_FastCharge_000034_CH27_structure.csv',
#   'processed_FastCharge_000035_CH12_structure.csv',
#   'processed_FastCharge_000036_CH48_structure.csv',
#   'processed_FastCharge_000038_CH13_structure.csv',
#   'processed_FastCharge_000040_CH32_structure.csv',
#   'processed_FastCharge_000041_CH10_structure.csv',
#   'processed_FastCharge_000042_CH36_structure.csv',
#   'processed_FastCharge_000043_CH16_structure.csv',
#   'processed_FastCharge_000047_CH21_structure.csv',
#   'processed_FastCharge_000049_CH37_structure.csv',
#   'processed_FastCharge_000052_CH41_structure.csv',
#   'processed_FastCharge_000053_CH42_structure.csv',
#   'processed_FastCharge_000054_CH15_structure.csv',
#   'processed_FastCharge_000055_CH20_structure.csv',
#   'processed_FastCharge_000056_CH11_structure.csv',
#   'processed_FastCharge_000059_CH33_structure.csv',
#   'processed_FastCharge_000060_CH29_structure.csv',
#   'processed_FastCharge_000061_CH43_structure.csv',
#   'processed_FastCharge_000062_CH47_structure.csv',
#   'processed_FastCharge_000064_CH39_structure.csv',
#   'processed_FastCharge_000068_CH38_structure.csv',
#   'processed_FastCharge_000069_CH25_structure.csv',
#   'processed_FastCharge_000070_CH46_structure.csv',
#   'processed_FastCharge_000071_CH40_structure.csv',
#   'processed_FastCharge_000072_CH34_structure.csv',
#   'processed_FastCharge_000073_CH35_structure.csv'],
#  '2018-04-12': ['processed_FastCharge_000001_CH16_structure.csv',
#   'processed_FastCharge_000001_CH30_structure.csv',
#   'processed_FastCharge_000001_CH38_structure.csv',
#   'processed_FastCharge_000002_CH10_structure.csv',
#   'processed_FastCharge_000002_CH18_structure.csv',
#   'processed_FastCharge_000002_CH2_structure.csv',
#   'processed_FastCharge_000002_CH34_structure.csv',
#   'processed_FastCharge_000002_CH42_structure.csv',
#   'processed_FastCharge_000002_CH47_structure.csv',
#   'processed_FastCharge_000002_CH7_structure.csv',
#   'processed_FastCharge_000006_CH11_structure.csv',
#   'processed_FastCharge_000006_CH19_structure.csv',
#   'processed_FastCharge_000006_CH27_structure.csv',
#   'processed_FastCharge_000006_CH35_structure.csv',
#   'processed_FastCharge_000006_CH3_structure.csv',
#   'processed_FastCharge_000006_CH43_structure.csv',
#   'processed_FastCharge_000006_CH48_structure.csv',
#   'processed_FastCharge_000006_CH8_structure.csv',
#   'processed_FastCharge_000007_CH24_structure.csv',
#   'processed_FastCharge_000007_CH39_structure.csv',
#   'processed_FastCharge_000012_CH13_structure.csv',
#   'processed_FastCharge_000012_CH15_structure.csv',
#   'processed_FastCharge_000012_CH21_structure.csv',
#   'processed_FastCharge_000012_CH23_structure.csv',
#   'processed_FastCharge_000012_CH29_structure.csv',
#   'processed_FastCharge_000012_CH37_structure.csv',
#   'processed_FastCharge_000012_CH45_structure.csv',
#   'processed_FastCharge_000012_CH5_structure.csv',
#   'processed_FastCharge_000015_CH12_structure.csv',
#   'processed_FastCharge_000015_CH14_structure.csv',
#   'processed_FastCharge_000015_CH20_structure.csv',
#   'processed_FastCharge_000015_CH22_structure.csv',
#   'processed_FastCharge_000015_CH28_structure.csv',
#   'processed_FastCharge_000015_CH36_structure.csv',
#   'processed_FastCharge_000015_CH44_structure.csv',
#   'processed_FastCharge_000015_CH4_structure.csv',
#   'processed_FastCharge_000017_CH17_structure.csv',
#   'processed_FastCharge_000017_CH1_structure.csv',
#   'processed_FastCharge_000017_CH25_structure.csv',
#   'processed_FastCharge_000017_CH33_structure.csv',
#   'processed_FastCharge_000017_CH41_structure.csv',
#   'processed_FastCharge_000017_CH46_structure.csv',
#   'processed_FastCharge_000017_CH6_structure.csv',
#   'processed_FastCharge_000017_CH9_structure.csv',
#   'processed_FastCharge_000050_CH32_structure.csv',
#   'processed_FastCharge_000050_CH40_structure.csv']}

# %%
# 모델의 입력 : 초기5주기+최근5주기(10)
#               VITC(전압, 전류, 온도, 방전용량, 4)
#               20%에 해당하는 데이터 포인트(200, 1사이클 당 1000개의 데이터 포인트
# 생성되는 데이터는 사이클 전체보다 9개 적음(ex; 1~5 + (5~10, ..., 737~742, 사이클 5부터 시작해 사이클 737까지))
import numpy as np

def preprocess_battery_data(battery_data, future_cycles=10, sample_frac=0.5, random_state=42):
    processed_data = []
    initial_cycles = battery_data[battery_data['cycles_interpolated_cycle_index'] < 5]
    total_cycles = battery_data['cycles_interpolated_cycle_index'].max() + 1

    # initial_samples = [initial_cycles[initial_cycles['cycles_interpolated_cycle_index'] == i].iloc[:]
                       # for i in range(5)]
    initial_samples = [initial_cycles[initial_cycles['cycles_interpolated_cycle_index'] == i].sample(frac=sample_frac, random_state=random_state)
                       for i in range(5)]

    cycle_indices = []

    for cycle_start in range(5, total_cycles - 5 + 1 - future_cycles):
        # recent_samples = [battery_data[battery_data['cycles_interpolated_cycle_index'] == i].iloc[:] 
                          # for i in range(cycle_start, cycle_start + 5)]
        recent_samples = [battery_data[battery_data['cycles_interpolated_cycle_index'] == i].sample(frac=sample_frac, random_state=random_state) 
                          for i in range(cycle_start, cycle_start + 5)]

        if any(len(cycle) < 200 for cycle in recent_samples):
            break

        combined_cycles = initial_samples + recent_samples
        reshaped_data = np.array([cycle[['cycles_interpolated_voltage', 
                                         'cycles_interpolated_current', 
                                         'cycles_interpolated_temperature', 
                                         'cycles_interpolated_discharge_capacity']].values for cycle in combined_cycles]).transpose(1, 2, 0)

        processed_data.append(reshaped_data)
        cycle_indices.append((cycle_start, cycle_start + 4))

    # for start, end in cycle_indices:
        # print(f"File uses cycles from {start} to {end}")

    return np.array(processed_data)

# %%
def preprocess_battery_data_for_second_CNN(battery_data, future_cycles=10, sample_frac=0.5, random_state=42):
    processed_data = []
    discharge_data = battery_data[battery_data['cycles_interpolated_step_type'] == 'discharge']
    total_cycles = discharge_data['cycles_interpolated_cycle_index'].max() + 1
    # initial_cycles = discharge_data[discharge_data['cycles_interpolated_cycle_index'] == 2]
    initial_cycles = discharge_data[discharge_data['cycles_interpolated_cycle_index'] == 2].sample(frac=sample_frac, random_state=random_state)
    cycle_indices = []

    for cycle_start in range(5, total_cycles - 5 + 1 - future_cycles):
        # recent_samples = [discharge_data[discharge_data['cycles_interpolated_cycle_index'] == i].iloc[:] 
                          # for i in range(cycle_start, cycle_start + 5)]
        recent_samples = [discharge_data[discharge_data['cycles_interpolated_cycle_index'] == i].sample(frac=sample_frac, random_state=random_state) 
                          for i in range(cycle_start, cycle_start + 5)]

        if any(len(cycle) < 200 for cycle in recent_samples):
            break

        initial_samples_reset = initial_cycles[['cycles_interpolated_voltage', 
                                                'cycles_interpolated_current', 
                                                'cycles_interpolated_temperature', 
                                                'cycles_interpolated_discharge_capacity']].iloc[:].reset_index(drop=True)
                                                # 'cycles_interpolated_temperature', 'cycles_interpolated_discharge_capacity']].iloc[:].reset_index(drop=True)
        differences = []
        for recent_cycle in recent_samples:
            recent_cycle_reset = recent_cycle[['cycles_interpolated_voltage', 'cycles_interpolated_current', 
                                               'cycles_interpolated_temperature', 'cycles_interpolated_discharge_capacity']].reset_index(drop=True)
            recent_cycle_reset['cycles_interpolated_voltage'] = 0 # 차이 계산할때 전압 제거
            difference = initial_samples_reset - recent_cycle_reset
            differences.append(difference.values)

        combined_difference = np.array(differences).transpose(1, 2, 0)

        processed_data.append(combined_difference)
        cycle_indices.append((cycle_start, cycle_start + 4))

    # for start, end in cycle_indices:
        # print(f"File uses cycles from {start} to {end}")

    return np.array(processed_data)

# %%
import numpy as np
import os
from tqdm import tqdm

# 처리할 그룹명 지정
selected_groups = ['2017-05-12', '2017-06-30', '2018-04-12']

# 파일 이름과 처리된 데이터를 매핑할 사전 초기화
grouped_processed_data_first_CNN = {}

# 첫 번째 CNN의 훈련 데이터 처리
for group_name in selected_groups[:-1]:  # 마지막 그룹 제외
    if group_name in grouped_dataframes:
        for file_name, battery_data in tqdm(zip(file_names[group_name], grouped_dataframes[group_name])):
            processed_dataset_first_CNN = preprocess_battery_data(battery_data)
            grouped_processed_data_first_CNN[file_name] = processed_dataset_first_CNN
    else:
        print(f"Group {group_name} not found in the dataset")

# 저장할 폴더 생성
save_folder = "processed_datasets(without preprocess)/with_filename(full, sampling)/train/first"
os.makedirs(save_folder, exist_ok=True)

# 처리된 데이터 저장
for file_name, data in grouped_processed_data_first_CNN.items():
    np.save(os.path.join(save_folder, f"{file_name}.npy"), data)

# 저장된 데이터 형태 확인
for file_name, data in grouped_processed_data_first_CNN.items():
    print(f"File: {file_name}, Data shape: {data.shape}")
# Out:
# 50it [05:14,  6.29s/it]
# 43it [02:13,  3.11s/it]
# File: processed_FastCharge_000003_CH39_structure.csv, Data shape: (724, 500, 4, 10)
# File: processed_FastCharge_000003_CH40_structure.csv, Data shape: (685, 500, 4, 10)
# File: processed_FastCharge_000004_CH1_structure.csv, Data shape: (645, 500, 4, 10)
# File: processed_FastCharge_000004_CH2_structure.csv, Data shape: (964, 500, 4, 10)
# File: processed_FastCharge_000004_CH3_structure.csv, Data shape: (1043, 500, 4, 10)
# File: processed_FastCharge_000008_CH47_structure.csv, Data shape: (598, 500, 4, 10)
# File: processed_FastCharge_000008_CH48_structure.csv, Data shape: (581, 500, 4, 10)
# File: processed_FastCharge_000013_CH13_structure.csv, Data shape: (888, 500, 4, 10)
# File: processed_FastCharge_000013_CH14_structure.csv, Data shape: (770, 500, 4, 10)
# File: processed_FastCharge_000014_CH23_structure.csv, Data shape: (844, 500, 4, 10)
# File: processed_FastCharge_000014_CH24_structure.csv, Data shape: (839, 500, 4, 10)
# File: processed_FastCharge_000018_CH18_structure.csv, Data shape: (770, 500, 4, 10)
# File: processed_FastCharge_000019_CH29_structure.csv, Data shape: (713, 500, 4, 10)
# File: processed_FastCharge_000019_CH30_structure.csv, Data shape: (739, 500, 4, 10)
# File: processed_FastCharge_000023_CH37_structure.csv, Data shape: (686, 500, 4, 10)
# File: processed_FastCharge_000023_CH38_structure.csv, Data shape: (630, 500, 4, 10)
# File: processed_FastCharge_000025_CH7_structure.csv, Data shape: (1056, 500, 4, 10)
# File: processed_FastCharge_000026_CH5_structure.csv, Data shape: (191, 500, 4, 10)
# File: processed_FastCharge_000026_CH6_structure.csv, Data shape: (465, 500, 4, 10)
# File: processed_FastCharge_000028_CH19_structure.csv, Data shape: (861, 500, 4, 10)
# File: processed_FastCharge_000028_CH20_structure.csv, Data shape: (1036, 500, 4, 10)
# File: processed_FastCharge_000029_CH10_structure.csv, Data shape: (618, 500, 4, 10)
# File: processed_FastCharge_000029_CH9_structure.csv, Data shape: (852, 500, 4, 10)
# File: processed_FastCharge_000037_CH21_structure.csv, Data shape: (884, 500, 4, 10)
# File: processed_FastCharge_000037_CH22_structure.csv, Data shape: (879, 500, 4, 10)
# File: processed_FastCharge_000039_CH27_structure.csv, Data shape: (842, 500, 4, 10)
# File: processed_FastCharge_000039_CH28_structure.csv, Data shape: (899, 500, 4, 10)
# File: processed_FastCharge_000044_CH11_structure.csv, Data shape: (516, 500, 4, 10)
# File: processed_FastCharge_000044_CH12_structure.csv, Data shape: (541, 500, 4, 10)
# File: processed_FastCharge_000045_CH1_structure.csv, Data shape: (1171, 500, 4, 10)
# File: processed_FastCharge_000045_CH2_structure.csv, Data shape: (1160, 500, 4, 10)
# File: processed_FastCharge_000045_CH3_structure.csv, Data shape: (1158, 500, 4, 10)
# File: processed_FastCharge_000046_CH31_structure.csv, Data shape: (873, 500, 4, 10)
# File: processed_FastCharge_000046_CH32_structure.csv, Data shape: (996, 500, 4, 10)
# File: processed_FastCharge_000048_CH43_structure.csv, Data shape: (948, 500, 4, 10)
# File: processed_FastCharge_000048_CH44_structure.csv, Data shape: (1033, 500, 4, 10)
# File: processed_FastCharge_000051_CH15_structure.csv, Data shape: (862, 500, 4, 10)
# File: processed_FastCharge_000051_CH16_structure.csv, Data shape: (701, 500, 4, 10)
# File: processed_FastCharge_000057_CH35_structure.csv, Data shape: (691, 500, 4, 10)
# File: processed_FastCharge_000057_CH36_structure.csv, Data shape: (858, 500, 4, 10)
# File: processed_FastCharge_000058_CH45_structure.csv, Data shape: (684, 500, 4, 10)
# File: processed_FastCharge_000058_CH46_structure.csv, Data shape: (633, 500, 4, 10)
# File: processed_FastCharge_000063_CH5_structure.csv, Data shape: (1208, 500, 4, 10)
# File: processed_FastCharge_000063_CH6_structure.csv, Data shape: (1208, 500, 4, 10)
# File: processed_FastCharge_000065_CH33_structure.csv, Data shape: (852, 500, 4, 10)
# File: processed_FastCharge_000065_CH34_structure.csv, Data shape: (824, 500, 4, 10)
# File: processed_FastCharge_000066_CH25_structure.csv, Data shape: (999, 500, 4, 10)
# File: processed_FastCharge_000066_CH26_structure.csv, Data shape: (836, 500, 4, 10)
# File: processed_FastCharge_000067_CH41_structure.csv, Data shape: (599, 500, 4, 10)
# File: processed_FastCharge_000067_CH42_structure.csv, Data shape: (607, 500, 4, 10)
# File: processed_FastCharge_000000_CH19_structure.csv, Data shape: (472, 500, 4, 10)
# File: processed_FastCharge_000005_CH18_structure.csv, Data shape: (506, 500, 4, 10)
# File: processed_FastCharge_000009_CH4_structure.csv, Data shape: (507, 500, 4, 10)
# File: processed_FastCharge_000009_CH7_structure.csv, Data shape: (470, 500, 4, 10)
# File: processed_FastCharge_000009_CH8_structure.csv, Data shape: (481, 500, 4, 10)
# File: processed_FastCharge_000010_CH44_structure.csv, Data shape: (470, 500, 4, 10)
# File: processed_FastCharge_000011_CH26_structure.csv, Data shape: (505, 500, 4, 10)
# File: processed_FastCharge_000016_CH17_structure.csv, Data shape: (508, 500, 4, 10)
# File: processed_FastCharge_000020_CH23_structure.csv, Data shape: (545, 500, 4, 10)
# File: processed_FastCharge_000021_CH28_structure.csv, Data shape: (474, 500, 4, 10)
# File: processed_FastCharge_000022_CH24_structure.csv, Data shape: (478, 500, 4, 10)
# File: processed_FastCharge_000024_CH45_structure.csv, Data shape: (462, 500, 4, 10)
# File: processed_FastCharge_000027_CH31_structure.csv, Data shape: (490, 500, 4, 10)
# File: processed_FastCharge_000030_CH30_structure.csv, Data shape: (492, 500, 4, 10)
# File: processed_FastCharge_000031_CH9_structure.csv, Data shape: (309, 500, 4, 10)
# File: processed_FastCharge_000032_CH22_structure.csv, Data shape: (523, 500, 4, 10)
# File: processed_FastCharge_000033_CH14_structure.csv, Data shape: (490, 500, 4, 10)
# File: processed_FastCharge_000034_CH27_structure.csv, Data shape: (488, 500, 4, 10)
# File: processed_FastCharge_000035_CH12_structure.csv, Data shape: (344, 500, 4, 10)
# File: processed_FastCharge_000036_CH48_structure.csv, Data shape: (728, 500, 4, 10)
# File: processed_FastCharge_000038_CH13_structure.csv, Data shape: (454, 500, 4, 10)
# File: processed_FastCharge_000040_CH32_structure.csv, Data shape: (502, 500, 4, 10)
# File: processed_FastCharge_000041_CH10_structure.csv, Data shape: (153, 500, 4, 10)
# File: processed_FastCharge_000042_CH36_structure.csv, Data shape: (469, 500, 4, 10)
# File: processed_FastCharge_000043_CH16_structure.csv, Data shape: (579, 500, 4, 10)
# File: processed_FastCharge_000047_CH21_structure.csv, Data shape: (503, 500, 4, 10)
# File: processed_FastCharge_000049_CH37_structure.csv, Data shape: (543, 500, 4, 10)
# File: processed_FastCharge_000052_CH41_structure.csv, Data shape: (513, 500, 4, 10)
# File: processed_FastCharge_000053_CH42_structure.csv, Data shape: (435, 500, 4, 10)
# File: processed_FastCharge_000054_CH15_structure.csv, Data shape: (528, 500, 4, 10)
# File: processed_FastCharge_000055_CH20_structure.csv, Data shape: (514, 500, 4, 10)
# File: processed_FastCharge_000056_CH11_structure.csv, Data shape: (447, 500, 4, 10)
# File: processed_FastCharge_000059_CH33_structure.csv, Data shape: (527, 500, 4, 10)
# File: processed_FastCharge_000060_CH29_structure.csv, Data shape: (503, 500, 4, 10)
# File: processed_FastCharge_000061_CH43_structure.csv, Data shape: (475, 500, 4, 10)
# File: processed_FastCharge_000062_CH47_structure.csv, Data shape: (432, 500, 4, 10)
# File: processed_FastCharge_000064_CH39_structure.csv, Data shape: (470, 500, 4, 10)
# File: processed_FastCharge_000068_CH38_structure.csv, Data shape: (485, 500, 4, 10)
# File: processed_FastCharge_000069_CH25_structure.csv, Data shape: (524, 500, 4, 10)
# File: processed_FastCharge_000070_CH46_structure.csv, Data shape: (497, 500, 4, 10)
# File: processed_FastCharge_000071_CH40_structure.csv, Data shape: (463, 500, 4, 10)
# File: processed_FastCharge_000072_CH34_structure.csv, Data shape: (529, 500, 4, 10)
# File: processed_FastCharge_000073_CH35_structure.csv, Data shape: (509, 500, 4, 10)

# %%
# 파일 이름과 처리된 데이터를 매핑할 사전 초기화
grouped_processed_data_second_CNN = {}

# 두 번째 CNN의 훈련 데이터 처리
for group_name in selected_groups[:-1]:  # 마지막 그룹 제외
    if group_name in grouped_dataframes:
        for file_name, battery_data in tqdm(zip(file_names[group_name], grouped_dataframes[group_name])):
            processed_dataset_second_CNN = preprocess_battery_data_for_second_CNN(battery_data)
            grouped_processed_data_second_CNN[file_name] = processed_dataset_second_CNN
    else:
        print(f"Group {group_name} not found in the dataset")

# 저장할 폴더 생성
save_folder = "processed_datasets(without preprocess)/with_filename(full, sampling)/train/second"
os.makedirs(save_folder, exist_ok=True)

# 처리된 데이터 저장
for file_name, data in grouped_processed_data_second_CNN.items():
    np.save(os.path.join(save_folder, f"{file_name}_second_CNN.npy"), data)

# 저장된 데이터 형태 확인
for file_name, data in grouped_processed_data_second_CNN.items():
    print(f"File: {file_name}, Data shape: {data.shape}")
# Out:
# 50it [05:45,  6.91s/it]
# 43it [02:26,  3.40s/it]
# File: processed_FastCharge_000003_CH39_structure.csv, Data shape: (724, 500, 4, 5)
# File: processed_FastCharge_000003_CH40_structure.csv, Data shape: (685, 500, 4, 5)
# File: processed_FastCharge_000004_CH1_structure.csv, Data shape: (645, 500, 4, 5)
# File: processed_FastCharge_000004_CH2_structure.csv, Data shape: (964, 500, 4, 5)
# File: processed_FastCharge_000004_CH3_structure.csv, Data shape: (1043, 500, 4, 5)
# File: processed_FastCharge_000008_CH47_structure.csv, Data shape: (598, 500, 4, 5)
# File: processed_FastCharge_000008_CH48_structure.csv, Data shape: (581, 500, 4, 5)
# File: processed_FastCharge_000013_CH13_structure.csv, Data shape: (888, 500, 4, 5)
# File: processed_FastCharge_000013_CH14_structure.csv, Data shape: (770, 500, 4, 5)
# File: processed_FastCharge_000014_CH23_structure.csv, Data shape: (844, 500, 4, 5)
# File: processed_FastCharge_000014_CH24_structure.csv, Data shape: (839, 500, 4, 5)
# File: processed_FastCharge_000018_CH18_structure.csv, Data shape: (770, 500, 4, 5)
# File: processed_FastCharge_000019_CH29_structure.csv, Data shape: (713, 500, 4, 5)
# File: processed_FastCharge_000019_CH30_structure.csv, Data shape: (739, 500, 4, 5)
# File: processed_FastCharge_000023_CH37_structure.csv, Data shape: (686, 500, 4, 5)
# File: processed_FastCharge_000023_CH38_structure.csv, Data shape: (630, 500, 4, 5)
# File: processed_FastCharge_000025_CH7_structure.csv, Data shape: (1056, 500, 4, 5)
# File: processed_FastCharge_000026_CH5_structure.csv, Data shape: (191, 500, 4, 5)
# File: processed_FastCharge_000026_CH6_structure.csv, Data shape: (465, 500, 4, 5)
# File: processed_FastCharge_000028_CH19_structure.csv, Data shape: (861, 500, 4, 5)
# File: processed_FastCharge_000028_CH20_structure.csv, Data shape: (1036, 500, 4, 5)
# File: processed_FastCharge_000029_CH10_structure.csv, Data shape: (618, 500, 4, 5)
# File: processed_FastCharge_000029_CH9_structure.csv, Data shape: (852, 500, 4, 5)
# File: processed_FastCharge_000037_CH21_structure.csv, Data shape: (884, 500, 4, 5)
# File: processed_FastCharge_000037_CH22_structure.csv, Data shape: (879, 500, 4, 5)
# File: processed_FastCharge_000039_CH27_structure.csv, Data shape: (842, 500, 4, 5)
# File: processed_FastCharge_000039_CH28_structure.csv, Data shape: (899, 500, 4, 5)
# File: processed_FastCharge_000044_CH11_structure.csv, Data shape: (516, 500, 4, 5)
# File: processed_FastCharge_000044_CH12_structure.csv, Data shape: (541, 500, 4, 5)
# File: processed_FastCharge_000045_CH1_structure.csv, Data shape: (1171, 500, 4, 5)
# File: processed_FastCharge_000045_CH2_structure.csv, Data shape: (1160, 500, 4, 5)
# File: processed_FastCharge_000045_CH3_structure.csv, Data shape: (1158, 500, 4, 5)
# File: processed_FastCharge_000046_CH31_structure.csv, Data shape: (873, 500, 4, 5)
# File: processed_FastCharge_000046_CH32_structure.csv, Data shape: (996, 500, 4, 5)
# File: processed_FastCharge_000048_CH43_structure.csv, Data shape: (948, 500, 4, 5)
# File: processed_FastCharge_000048_CH44_structure.csv, Data shape: (1033, 500, 4, 5)
# File: processed_FastCharge_000051_CH15_structure.csv, Data shape: (862, 500, 4, 5)
# File: processed_FastCharge_000051_CH16_structure.csv, Data shape: (701, 500, 4, 5)
# File: processed_FastCharge_000057_CH35_structure.csv, Data shape: (691, 500, 4, 5)
# File: processed_FastCharge_000057_CH36_structure.csv, Data shape: (858, 500, 4, 5)
# File: processed_FastCharge_000058_CH45_structure.csv, Data shape: (684, 500, 4, 5)
# File: processed_FastCharge_000058_CH46_structure.csv, Data shape: (633, 500, 4, 5)
# File: processed_FastCharge_000063_CH5_structure.csv, Data shape: (1208, 500, 4, 5)
# File: processed_FastCharge_000063_CH6_structure.csv, Data shape: (1208, 500, 4, 5)
# File: processed_FastCharge_000065_CH33_structure.csv, Data shape: (852, 500, 4, 5)
# File: processed_FastCharge_000065_CH34_structure.csv, Data shape: (824, 500, 4, 5)
# File: processed_FastCharge_000066_CH25_structure.csv, Data shape: (999, 500, 4, 5)
# File: processed_FastCharge_000066_CH26_structure.csv, Data shape: (836, 500, 4, 5)
# File: processed_FastCharge_000067_CH41_structure.csv, Data shape: (599, 500, 4, 5)
# File: processed_FastCharge_000067_CH42_structure.csv, Data shape: (607, 500, 4, 5)
# File: processed_FastCharge_000000_CH19_structure.csv, Data shape: (472, 500, 4, 5)
# File: processed_FastCharge_000005_CH18_structure.csv, Data shape: (506, 500, 4, 5)
# File: processed_FastCharge_000009_CH4_structure.csv, Data shape: (507, 500, 4, 5)
# File: processed_FastCharge_000009_CH7_structure.csv, Data shape: (470, 500, 4, 5)
# File: processed_FastCharge_000009_CH8_structure.csv, Data shape: (481, 500, 4, 5)
# File: processed_FastCharge_000010_CH44_structure.csv, Data shape: (470, 500, 4, 5)
# File: processed_FastCharge_000011_CH26_structure.csv, Data shape: (505, 500, 4, 5)
# File: processed_FastCharge_000016_CH17_structure.csv, Data shape: (508, 500, 4, 5)
# File: processed_FastCharge_000020_CH23_structure.csv, Data shape: (545, 500, 4, 5)
# File: processed_FastCharge_000021_CH28_structure.csv, Data shape: (474, 500, 4, 5)
# File: processed_FastCharge_000022_CH24_structure.csv, Data shape: (478, 500, 4, 5)
# File: processed_FastCharge_000024_CH45_structure.csv, Data shape: (462, 500, 4, 5)
# File: processed_FastCharge_000027_CH31_structure.csv, Data shape: (490, 500, 4, 5)
# File: processed_FastCharge_000030_CH30_structure.csv, Data shape: (492, 500, 4, 5)
# File: processed_FastCharge_000031_CH9_structure.csv, Data shape: (309, 500, 4, 5)
# File: processed_FastCharge_000032_CH22_structure.csv, Data shape: (523, 500, 4, 5)
# File: processed_FastCharge_000033_CH14_structure.csv, Data shape: (490, 500, 4, 5)
# File: processed_FastCharge_000034_CH27_structure.csv, Data shape: (488, 500, 4, 5)
# File: processed_FastCharge_000035_CH12_structure.csv, Data shape: (344, 500, 4, 5)
# File: processed_FastCharge_000036_CH48_structure.csv, Data shape: (728, 500, 4, 5)
# File: processed_FastCharge_000038_CH13_structure.csv, Data shape: (454, 500, 4, 5)
# File: processed_FastCharge_000040_CH32_structure.csv, Data shape: (502, 500, 4, 5)
# File: processed_FastCharge_000041_CH10_structure.csv, Data shape: (153, 500, 4, 5)
# File: processed_FastCharge_000042_CH36_structure.csv, Data shape: (469, 500, 4, 5)
# File: processed_FastCharge_000043_CH16_structure.csv, Data shape: (579, 500, 4, 5)
# File: processed_FastCharge_000047_CH21_structure.csv, Data shape: (503, 500, 4, 5)
# File: processed_FastCharge_000049_CH37_structure.csv, Data shape: (543, 500, 4, 5)
# File: processed_FastCharge_000052_CH41_structure.csv, Data shape: (513, 500, 4, 5)
# File: processed_FastCharge_000053_CH42_structure.csv, Data shape: (435, 500, 4, 5)
# File: processed_FastCharge_000054_CH15_structure.csv, Data shape: (528, 500, 4, 5)
# File: processed_FastCharge_000055_CH20_structure.csv, Data shape: (514, 500, 4, 5)
# File: processed_FastCharge_000056_CH11_structure.csv, Data shape: (447, 500, 4, 5)
# File: processed_FastCharge_000059_CH33_structure.csv, Data shape: (527, 500, 4, 5)
# File: processed_FastCharge_000060_CH29_structure.csv, Data shape: (503, 500, 4, 5)
# File: processed_FastCharge_000061_CH43_structure.csv, Data shape: (475, 500, 4, 5)
# File: processed_FastCharge_000062_CH47_structure.csv, Data shape: (432, 500, 4, 5)
# File: processed_FastCharge_000064_CH39_structure.csv, Data shape: (470, 500, 4, 5)
# File: processed_FastCharge_000068_CH38_structure.csv, Data shape: (485, 500, 4, 5)
# File: processed_FastCharge_000069_CH25_structure.csv, Data shape: (524, 500, 4, 5)
# File: processed_FastCharge_000070_CH46_structure.csv, Data shape: (497, 500, 4, 5)
# File: processed_FastCharge_000071_CH40_structure.csv, Data shape: (463, 500, 4, 5)
# File: processed_FastCharge_000072_CH34_structure.csv, Data shape: (529, 500, 4, 5)
# File: processed_FastCharge_000073_CH35_structure.csv, Data shape: (509, 500, 4, 5)

# %%
import numpy as np
import os
from tqdm import tqdm

# 처리할 그룹명 지정
selected_groups = ['2017-05-12', '2017-06-30', '2018-04-12']

# 파일 이름과 처리된 데이터를 매핑할 사전 초기화
grouped_processed_data_test_first_CNN = {}
grouped_processed_data_test_second_CNN = {}

# 선택된 그룹 중 마지막 그룹을 테스트 데이터로 사용
test_group_name = selected_groups[-1]

if test_group_name in grouped_dataframes:
    # 해당 그룹의 각 배터리 데이터셋에 대해 전처리 수행 (테스트 데이터)
    for file_name, battery_data in tqdm(zip(file_names[test_group_name], grouped_dataframes[test_group_name]), desc=f"Processing {test_group_name}"):
        processed_dataset_first_CNN = preprocess_battery_data(battery_data)
        processed_dataset_second_CNN = preprocess_battery_data_for_second_CNN(battery_data)
        grouped_processed_data_test_first_CNN[file_name] = processed_dataset_first_CNN
        grouped_processed_data_test_second_CNN[file_name] = processed_dataset_second_CNN
else:
    print(f"Test group {test_group_name} not found in the dataset")

# 저장할 폴더 생성
save_folder = "processed_datasets(without preprocess)/with_filename(full, sampling)/"
first_save_folder = save_folder+"test/first"
second_save_folder = save_folder+"test/second"
os.makedirs(first_save_folder, exist_ok=True)
os.makedirs(second_save_folder, exist_ok=True)

# 처리된 데이터 저장
for file_name, data in tqdm(grouped_processed_data_test_first_CNN.items(), desc="Saving first CNN test data"):
    np.save(os.path.join(first_save_folder, f"{file_name}_test_first_CNN.npy"), data)
for file_name, data in tqdm(grouped_processed_data_test_second_CNN.items(), desc="Saving second CNN test data"):
    np.save(os.path.join(second_save_folder, f"{file_name}_test_second_CNN.npy"), data)

# 저장된 데이터 형태 확인
for file_name, data in grouped_processed_data_test_first_CNN.items():
    print(f"File: {file_name}, Test data shape for first CNN: {data.shape}")
for file_name, data in grouped_processed_data_test_second_CNN.items():
    print(f"File: {file_name}, Test data shape for second CNN: {data.shape}")
# Out:
# Processing 2018-04-12: 46it [16:52, 22.02s/it]
# Saving first CNN test data: 100%|██████████████████████████████████████████████████████| 46/46 [00:05<00:00,  8.40it/s]
# Saving second CNN test data: 100%|█████████████████████████████████████████████████████| 46/46 [00:02<00:00, 16.36it/s]
# File: processed_FastCharge_000001_CH16_structure.csv, Test data shape for first CNN: (649, 500, 4, 10)
# File: processed_FastCharge_000001_CH30_structure.csv, Test data shape for first CNN: (754, 500, 4, 10)
# File: processed_FastCharge_000001_CH38_structure.csv, Test data shape for first CNN: (523, 500, 4, 10)
# File: processed_FastCharge_000002_CH10_structure.csv, Test data shape for first CNN: (991, 500, 4, 10)
# File: processed_FastCharge_000002_CH18_structure.csv, Test data shape for first CNN: (810, 500, 4, 10)
# File: processed_FastCharge_000002_CH2_structure.csv, Test data shape for first CNN: (795, 500, 4, 10)
# File: processed_FastCharge_000002_CH34_structure.csv, Test data shape for first CNN: (807, 500, 4, 10)
# File: processed_FastCharge_000002_CH42_structure.csv, Test data shape for first CNN: (1266, 500, 4, 10)
# File: processed_FastCharge_000002_CH47_structure.csv, Test data shape for first CNN: (1917, 500, 4, 10)
# File: processed_FastCharge_000002_CH7_structure.csv, Test data shape for first CNN: (1028, 500, 4, 10)
# File: processed_FastCharge_000006_CH11_structure.csv, Test data shape for first CNN: (1045, 500, 4, 10)
# File: processed_FastCharge_000006_CH19_structure.csv, Test data shape for first CNN: (1021, 500, 4, 10)
# File: processed_FastCharge_000006_CH27_structure.csv, Test data shape for first CNN: (1297, 500, 4, 10)
# File: processed_FastCharge_000006_CH35_structure.csv, Test data shape for first CNN: (971, 500, 4, 10)
# File: processed_FastCharge_000006_CH3_structure.csv, Test data shape for first CNN: (917, 500, 4, 10)
# File: processed_FastCharge_000006_CH43_structure.csv, Test data shape for first CNN: (1140, 500, 4, 10)
# File: processed_FastCharge_000006_CH48_structure.csv, Test data shape for first CNN: (1138, 500, 4, 10)
# File: processed_FastCharge_000006_CH8_structure.csv, Test data shape for first CNN: (922, 500, 4, 10)
# File: processed_FastCharge_000007_CH24_structure.csv, Test data shape for first CNN: (858, 500, 4, 10)
# File: processed_FastCharge_000007_CH39_structure.csv, Test data shape for first CNN: (840, 500, 4, 10)
# File: processed_FastCharge_000012_CH13_structure.csv, Test data shape for first CNN: (1097, 500, 4, 10)
# File: processed_FastCharge_000012_CH15_structure.csv, Test data shape for first CNN: (810, 500, 4, 10)
# File: processed_FastCharge_000012_CH21_structure.csv, Test data shape for first CNN: (914, 500, 4, 10)
# File: processed_FastCharge_000012_CH23_structure.csv, Test data shape for first CNN: (840, 500, 4, 10)
# File: processed_FastCharge_000012_CH29_structure.csv, Test data shape for first CNN: (1137, 500, 4, 10)
# File: processed_FastCharge_000012_CH37_structure.csv, Test data shape for first CNN: (832, 500, 4, 10)
# File: processed_FastCharge_000012_CH45_structure.csv, Test data shape for first CNN: (905, 500, 4, 10)
# File: processed_FastCharge_000012_CH5_structure.csv, Test data shape for first CNN: (768, 500, 4, 10)
# File: processed_FastCharge_000015_CH12_structure.csv, Test data shape for first CNN: (1249, 500, 4, 10)
# File: processed_FastCharge_000015_CH14_structure.csv, Test data shape for first CNN: (1030, 500, 4, 10)
# File: processed_FastCharge_000015_CH20_structure.csv, Test data shape for first CNN: (799, 500, 4, 10)
# File: processed_FastCharge_000015_CH22_structure.csv, Test data shape for first CNN: (798, 500, 4, 10)
# File: processed_FastCharge_000015_CH28_structure.csv, Test data shape for first CNN: (1128, 500, 4, 10)
# File: processed_FastCharge_000015_CH36_structure.csv, Test data shape for first CNN: (1010, 500, 4, 10)
# File: processed_FastCharge_000015_CH44_structure.csv, Test data shape for first CNN: (1075, 500, 4, 10)
# File: processed_FastCharge_000015_CH4_structure.csv, Test data shape for first CNN: (778, 500, 4, 10)
# File: processed_FastCharge_000017_CH17_structure.csv, Test data shape for first CNN: (1818, 500, 4, 10)
# File: processed_FastCharge_000017_CH1_structure.csv, Test data shape for first CNN: (1060, 500, 4, 10)
# File: processed_FastCharge_000017_CH25_structure.csv, Test data shape for first CNN: (1620, 500, 4, 10)
# File: processed_FastCharge_000017_CH33_structure.csv, Test data shape for first CNN: (2171, 500, 4, 10)
# File: processed_FastCharge_000017_CH41_structure.csv, Test data shape for first CNN: (2220, 500, 4, 10)
# File: processed_FastCharge_000017_CH46_structure.csv, Test data shape for first CNN: (1372, 500, 4, 10)
# File: processed_FastCharge_000017_CH6_structure.csv, Test data shape for first CNN: (1624, 500, 4, 10)
# File: processed_FastCharge_000017_CH9_structure.csv, Test data shape for first CNN: (1783, 500, 4, 10)
# File: processed_FastCharge_000050_CH32_structure.csv, Test data shape for first CNN: (984, 500, 4, 10)
# File: processed_FastCharge_000050_CH40_structure.csv, Test data shape for first CNN: (713, 500, 4, 10)
# File: processed_FastCharge_000001_CH16_structure.csv, Test data shape for second CNN: (649, 500, 4, 5)
# File: processed_FastCharge_000001_CH30_structure.csv, Test data shape for second CNN: (754, 500, 4, 5)
# File: processed_FastCharge_000001_CH38_structure.csv, Test data shape for second CNN: (523, 500, 4, 5)
# File: processed_FastCharge_000002_CH10_structure.csv, Test data shape for second CNN: (991, 500, 4, 5)
# File: processed_FastCharge_000002_CH18_structure.csv, Test data shape for second CNN: (810, 500, 4, 5)
# File: processed_FastCharge_000002_CH2_structure.csv, Test data shape for second CNN: (795, 500, 4, 5)
# File: processed_FastCharge_000002_CH34_structure.csv, Test data shape for second CNN: (807, 500, 4, 5)
# File: processed_FastCharge_000002_CH42_structure.csv, Test data shape for second CNN: (1266, 500, 4, 5)
# File: processed_FastCharge_000002_CH47_structure.csv, Test data shape for second CNN: (1917, 500, 4, 5)
# File: processed_FastCharge_000002_CH7_structure.csv, Test data shape for second CNN: (1028, 500, 4, 5)
# File: processed_FastCharge_000006_CH11_structure.csv, Test data shape for second CNN: (1045, 500, 4, 5)
# File: processed_FastCharge_000006_CH19_structure.csv, Test data shape for second CNN: (1021, 500, 4, 5)
# File: processed_FastCharge_000006_CH27_structure.csv, Test data shape for second CNN: (1297, 500, 4, 5)
# File: processed_FastCharge_000006_CH35_structure.csv, Test data shape for second CNN: (971, 500, 4, 5)
# File: processed_FastCharge_000006_CH3_structure.csv, Test data shape for second CNN: (917, 500, 4, 5)
# File: processed_FastCharge_000006_CH43_structure.csv, Test data shape for second CNN: (1140, 500, 4, 5)
# File: processed_FastCharge_000006_CH48_structure.csv, Test data shape for second CNN: (1138, 500, 4, 5)
# File: processed_FastCharge_000006_CH8_structure.csv, Test data shape for second CNN: (922, 500, 4, 5)
# File: processed_FastCharge_000007_CH24_structure.csv, Test data shape for second CNN: (858, 500, 4, 5)
# File: processed_FastCharge_000007_CH39_structure.csv, Test data shape for second CNN: (840, 500, 4, 5)
# File: processed_FastCharge_000012_CH13_structure.csv, Test data shape for second CNN: (1097, 500, 4, 5)
# File: processed_FastCharge_000012_CH15_structure.csv, Test data shape for second CNN: (810, 500, 4, 5)
# File: processed_FastCharge_000012_CH21_structure.csv, Test data shape for second CNN: (914, 500, 4, 5)
# File: processed_FastCharge_000012_CH23_structure.csv, Test data shape for second CNN: (840, 500, 4, 5)
# File: processed_FastCharge_000012_CH29_structure.csv, Test data shape for second CNN: (1137, 500, 4, 5)
# File: processed_FastCharge_000012_CH37_structure.csv, Test data shape for second CNN: (832, 500, 4, 5)
# File: processed_FastCharge_000012_CH45_structure.csv, Test data shape for second CNN: (905, 500, 4, 5)
# File: processed_FastCharge_000012_CH5_structure.csv, Test data shape for second CNN: (768, 500, 4, 5)
# File: processed_FastCharge_000015_CH12_structure.csv, Test data shape for second CNN: (1249, 500, 4, 5)
# File: processed_FastCharge_000015_CH14_structure.csv, Test data shape for second CNN: (1030, 500, 4, 5)
# File: processed_FastCharge_000015_CH20_structure.csv, Test data shape for second CNN: (799, 500, 4, 5)
# File: processed_FastCharge_000015_CH22_structure.csv, Test data shape for second CNN: (798, 500, 4, 5)
# File: processed_FastCharge_000015_CH28_structure.csv, Test data shape for second CNN: (1128, 500, 4, 5)
# File: processed_FastCharge_000015_CH36_structure.csv, Test data shape for second CNN: (1010, 500, 4, 5)
# File: processed_FastCharge_000015_CH44_structure.csv, Test data shape for second CNN: (1075, 500, 4, 5)
# File: processed_FastCharge_000015_CH4_structure.csv, Test data shape for second CNN: (778, 500, 4, 5)
# File: processed_FastCharge_000017_CH17_structure.csv, Test data shape for second CNN: (1818, 500, 4, 5)
# File: processed_FastCharge_000017_CH1_structure.csv, Test data shape for second CNN: (1060, 500, 4, 5)
# File: processed_FastCharge_000017_CH25_structure.csv, Test data shape for second CNN: (1620, 500, 4, 5)
# File: processed_FastCharge_000017_CH33_structure.csv, Test data shape for second CNN: (2171, 500, 4, 5)
# File: processed_FastCharge_000017_CH41_structure.csv, Test data shape for second CNN: (2220, 500, 4, 5)
# File: processed_FastCharge_000017_CH46_structure.csv, Test data shape for second CNN: (1372, 500, 4, 5)
# File: processed_FastCharge_000017_CH6_structure.csv, Test data shape for second CNN: (1624, 500, 4, 5)
# File: processed_FastCharge_000017_CH9_structure.csv, Test data shape for second CNN: (1783, 500, 4, 5)
# File: processed_FastCharge_000050_CH32_structure.csv, Test data shape for second CNN: (984, 500, 4, 5)
# File: processed_FastCharge_000050_CH40_structure.csv, Test data shape for second CNN: (713, 500, 4, 5)

# %%
import numpy as np
import os

def create_and_save_target_data(grouped_dataframes, file_names, selected_groups, save_folder, look_ahead_cycles=19):
    # 파일 이름과 타겟 데이터를 매핑할 사전 초기화
    grouped_target_data = {}

    # 선택된 그룹의 각 배터리 데이터셋에서 타겟 데이터 추출
    for group_name in selected_groups:
        if group_name in grouped_dataframes:
            for file_name, battery_data in zip(file_names[group_name], grouped_dataframes[group_name]):
                target_data = []
                total_cycles = battery_data['cycles_interpolated_cycle_index'].max() + 1
                for cycle_index in range(total_cycles - look_ahead_cycles):
                    future_cycle_index = cycle_index + look_ahead_cycles
                    if future_cycle_index < total_cycles:
                        target_capacity = battery_data[battery_data['cycles_interpolated_cycle_index'] == future_cycle_index].iloc[0]['cycles_interpolated_discharge_capacity']
                        target_data.append(target_capacity)
                grouped_target_data[file_name] = np.array(target_data)
        else:
            print(f"Group {group_name} not found in the dataset")

    # 타겟 데이터 저장
    for file_name, data in grouped_target_data.items():
        np.save(os.path.join(save_folder, f"{file_name}_target.npy"), data)

    return grouped_target_data

# %%
save_folder = "processed_datasets(without preprocess)/with_filename(full, sampling)/target/train"
os.makedirs(save_folder, exist_ok=True)

# 훈련 데이터에 대한 타겟 데이터 생성 및 저장
grouped_target_data_train = create_and_save_target_data(grouped_dataframes, file_names, selected_groups[:2], save_folder)

# 저장된 데이터 형태 확인
for file_name, data in grouped_target_data_train.items():
    print(f"File: {file_name}, Target data shape: {data.shape}")
# Out:
# File: processed_FastCharge_000003_CH39_structure.csv, Target data shape: (724,)
# File: processed_FastCharge_000003_CH40_structure.csv, Target data shape: (685,)
# File: processed_FastCharge_000004_CH1_structure.csv, Target data shape: (645,)
# File: processed_FastCharge_000004_CH2_structure.csv, Target data shape: (964,)
# File: processed_FastCharge_000004_CH3_structure.csv, Target data shape: (1043,)
# File: processed_FastCharge_000008_CH47_structure.csv, Target data shape: (598,)
# File: processed_FastCharge_000008_CH48_structure.csv, Target data shape: (581,)
# File: processed_FastCharge_000013_CH13_structure.csv, Target data shape: (888,)
# File: processed_FastCharge_000013_CH14_structure.csv, Target data shape: (770,)
# File: processed_FastCharge_000014_CH23_structure.csv, Target data shape: (844,)
# File: processed_FastCharge_000014_CH24_structure.csv, Target data shape: (839,)
# File: processed_FastCharge_000018_CH18_structure.csv, Target data shape: (770,)
# File: processed_FastCharge_000019_CH29_structure.csv, Target data shape: (713,)
# File: processed_FastCharge_000019_CH30_structure.csv, Target data shape: (739,)
# File: processed_FastCharge_000023_CH37_structure.csv, Target data shape: (686,)
# File: processed_FastCharge_000023_CH38_structure.csv, Target data shape: (630,)
# File: processed_FastCharge_000025_CH7_structure.csv, Target data shape: (1056,)
# File: processed_FastCharge_000026_CH5_structure.csv, Target data shape: (191,)
# File: processed_FastCharge_000026_CH6_structure.csv, Target data shape: (465,)
# File: processed_FastCharge_000028_CH19_structure.csv, Target data shape: (861,)
# File: processed_FastCharge_000028_CH20_structure.csv, Target data shape: (1036,)
# File: processed_FastCharge_000029_CH10_structure.csv, Target data shape: (618,)
# File: processed_FastCharge_000029_CH9_structure.csv, Target data shape: (852,)
# File: processed_FastCharge_000037_CH21_structure.csv, Target data shape: (884,)
# File: processed_FastCharge_000037_CH22_structure.csv, Target data shape: (879,)
# File: processed_FastCharge_000039_CH27_structure.csv, Target data shape: (842,)
# File: processed_FastCharge_000039_CH28_structure.csv, Target data shape: (899,)
# File: processed_FastCharge_000044_CH11_structure.csv, Target data shape: (516,)
# File: processed_FastCharge_000044_CH12_structure.csv, Target data shape: (541,)
# File: processed_FastCharge_000045_CH1_structure.csv, Target data shape: (1171,)
# File: processed_FastCharge_000045_CH2_structure.csv, Target data shape: (1160,)
# File: processed_FastCharge_000045_CH3_structure.csv, Target data shape: (1158,)
# File: processed_FastCharge_000046_CH31_structure.csv, Target data shape: (873,)
# File: processed_FastCharge_000046_CH32_structure.csv, Target data shape: (996,)
# File: processed_FastCharge_000048_CH43_structure.csv, Target data shape: (948,)
# File: processed_FastCharge_000048_CH44_structure.csv, Target data shape: (1033,)
# File: processed_FastCharge_000051_CH15_structure.csv, Target data shape: (862,)
# File: processed_FastCharge_000051_CH16_structure.csv, Target data shape: (701,)
# File: processed_FastCharge_000057_CH35_structure.csv, Target data shape: (691,)
# File: processed_FastCharge_000057_CH36_structure.csv, Target data shape: (858,)
# File: processed_FastCharge_000058_CH45_structure.csv, Target data shape: (684,)
# File: processed_FastCharge_000058_CH46_structure.csv, Target data shape: (633,)
# File: processed_FastCharge_000063_CH5_structure.csv, Target data shape: (1208,)
# File: processed_FastCharge_000063_CH6_structure.csv, Target data shape: (1208,)
# File: processed_FastCharge_000065_CH33_structure.csv, Target data shape: (852,)
# File: processed_FastCharge_000065_CH34_structure.csv, Target data shape: (824,)
# File: processed_FastCharge_000066_CH25_structure.csv, Target data shape: (999,)
# File: processed_FastCharge_000066_CH26_structure.csv, Target data shape: (836,)
# File: processed_FastCharge_000067_CH41_structure.csv, Target data shape: (599,)
# File: processed_FastCharge_000067_CH42_structure.csv, Target data shape: (607,)
# File: processed_FastCharge_000000_CH19_structure.csv, Target data shape: (472,)
# File: processed_FastCharge_000005_CH18_structure.csv, Target data shape: (506,)
# File: processed_FastCharge_000009_CH4_structure.csv, Target data shape: (507,)
# File: processed_FastCharge_000009_CH7_structure.csv, Target data shape: (470,)
# File: processed_FastCharge_000009_CH8_structure.csv, Target data shape: (481,)
# File: processed_FastCharge_000010_CH44_structure.csv, Target data shape: (470,)
# File: processed_FastCharge_000011_CH26_structure.csv, Target data shape: (505,)
# File: processed_FastCharge_000016_CH17_structure.csv, Target data shape: (508,)
# File: processed_FastCharge_000020_CH23_structure.csv, Target data shape: (545,)
# File: processed_FastCharge_000021_CH28_structure.csv, Target data shape: (474,)
# File: processed_FastCharge_000022_CH24_structure.csv, Target data shape: (478,)
# File: processed_FastCharge_000024_CH45_structure.csv, Target data shape: (462,)
# File: processed_FastCharge_000027_CH31_structure.csv, Target data shape: (490,)
# File: processed_FastCharge_000030_CH30_structure.csv, Target data shape: (492,)
# File: processed_FastCharge_000031_CH9_structure.csv, Target data shape: (309,)
# File: processed_FastCharge_000032_CH22_structure.csv, Target data shape: (523,)
# File: processed_FastCharge_000033_CH14_structure.csv, Target data shape: (490,)
# File: processed_FastCharge_000034_CH27_structure.csv, Target data shape: (488,)
# File: processed_FastCharge_000035_CH12_structure.csv, Target data shape: (344,)
# File: processed_FastCharge_000036_CH48_structure.csv, Target data shape: (728,)
# File: processed_FastCharge_000038_CH13_structure.csv, Target data shape: (454,)
# File: processed_FastCharge_000040_CH32_structure.csv, Target data shape: (502,)
# File: processed_FastCharge_000041_CH10_structure.csv, Target data shape: (153,)
# File: processed_FastCharge_000042_CH36_structure.csv, Target data shape: (469,)
# File: processed_FastCharge_000043_CH16_structure.csv, Target data shape: (579,)
# File: processed_FastCharge_000047_CH21_structure.csv, Target data shape: (503,)
# File: processed_FastCharge_000049_CH37_structure.csv, Target data shape: (543,)
# File: processed_FastCharge_000052_CH41_structure.csv, Target data shape: (513,)
# File: processed_FastCharge_000053_CH42_structure.csv, Target data shape: (435,)
# File: processed_FastCharge_000054_CH15_structure.csv, Target data shape: (528,)
# File: processed_FastCharge_000055_CH20_structure.csv, Target data shape: (514,)
# File: processed_FastCharge_000056_CH11_structure.csv, Target data shape: (447,)
# File: processed_FastCharge_000059_CH33_structure.csv, Target data shape: (527,)
# File: processed_FastCharge_000060_CH29_structure.csv, Target data shape: (503,)
# File: processed_FastCharge_000061_CH43_structure.csv, Target data shape: (475,)
# File: processed_FastCharge_000062_CH47_structure.csv, Target data shape: (432,)
# File: processed_FastCharge_000064_CH39_structure.csv, Target data shape: (470,)
# File: processed_FastCharge_000068_CH38_structure.csv, Target data shape: (485,)
# File: processed_FastCharge_000069_CH25_structure.csv, Target data shape: (524,)
# File: processed_FastCharge_000070_CH46_structure.csv, Target data shape: (497,)
# File: processed_FastCharge_000071_CH40_structure.csv, Target data shape: (463,)
# File: processed_FastCharge_000072_CH34_structure.csv, Target data shape: (529,)
# File: processed_FastCharge_000073_CH35_structure.csv, Target data shape: (509,)

# %%
save_folder = "processed_datasets(without preprocess)/with_filename(full, sampling)/target/test"
os.makedirs(save_folder, exist_ok=True)

# 훈련 데이터에 대한 타겟 데이터 생성 및 저장
grouped_target_data_train = create_and_save_target_data(grouped_dataframes, file_names, selected_groups[2:], save_folder)

# 저장된 데이터 형태 확인
for file_name, data in grouped_target_data_train.items():
    print(f"File: {file_name}, Target data shape: {data.shape}")
# Out:
# File: processed_FastCharge_000001_CH16_structure.csv, Target data shape: (649,)
# File: processed_FastCharge_000001_CH30_structure.csv, Target data shape: (754,)
# File: processed_FastCharge_000001_CH38_structure.csv, Target data shape: (523,)
# File: processed_FastCharge_000002_CH10_structure.csv, Target data shape: (991,)
# File: processed_FastCharge_000002_CH18_structure.csv, Target data shape: (810,)
# File: processed_FastCharge_000002_CH2_structure.csv, Target data shape: (795,)
# File: processed_FastCharge_000002_CH34_structure.csv, Target data shape: (807,)
# File: processed_FastCharge_000002_CH42_structure.csv, Target data shape: (1266,)
# File: processed_FastCharge_000002_CH47_structure.csv, Target data shape: (1917,)
# File: processed_FastCharge_000002_CH7_structure.csv, Target data shape: (1028,)
# File: processed_FastCharge_000006_CH11_structure.csv, Target data shape: (1045,)
# File: processed_FastCharge_000006_CH19_structure.csv, Target data shape: (1021,)
# File: processed_FastCharge_000006_CH27_structure.csv, Target data shape: (1297,)
# File: processed_FastCharge_000006_CH35_structure.csv, Target data shape: (971,)
# File: processed_FastCharge_000006_CH3_structure.csv, Target data shape: (917,)
# File: processed_FastCharge_000006_CH43_structure.csv, Target data shape: (1140,)
# File: processed_FastCharge_000006_CH48_structure.csv, Target data shape: (1138,)
# File: processed_FastCharge_000006_CH8_structure.csv, Target data shape: (922,)
# File: processed_FastCharge_000007_CH24_structure.csv, Target data shape: (858,)
# File: processed_FastCharge_000007_CH39_structure.csv, Target data shape: (840,)
# File: processed_FastCharge_000012_CH13_structure.csv, Target data shape: (1097,)
# File: processed_FastCharge_000012_CH15_structure.csv, Target data shape: (810,)
# File: processed_FastCharge_000012_CH21_structure.csv, Target data shape: (914,)
# File: processed_FastCharge_000012_CH23_structure.csv, Target data shape: (840,)
# File: processed_FastCharge_000012_CH29_structure.csv, Target data shape: (1137,)
# File: processed_FastCharge_000012_CH37_structure.csv, Target data shape: (832,)
# File: processed_FastCharge_000012_CH45_structure.csv, Target data shape: (905,)
# File: processed_FastCharge_000012_CH5_structure.csv, Target data shape: (768,)
# File: processed_FastCharge_000015_CH12_structure.csv, Target data shape: (1249,)
# File: processed_FastCharge_000015_CH14_structure.csv, Target data shape: (1030,)
# File: processed_FastCharge_000015_CH20_structure.csv, Target data shape: (799,)
# File: processed_FastCharge_000015_CH22_structure.csv, Target data shape: (798,)
# File: processed_FastCharge_000015_CH28_structure.csv, Target data shape: (1128,)
# File: processed_FastCharge_000015_CH36_structure.csv, Target data shape: (1010,)
# File: processed_FastCharge_000015_CH44_structure.csv, Target data shape: (1075,)
# File: processed_FastCharge_000015_CH4_structure.csv, Target data shape: (778,)
# File: processed_FastCharge_000017_CH17_structure.csv, Target data shape: (1818,)
# File: processed_FastCharge_000017_CH1_structure.csv, Target data shape: (1060,)
# File: processed_FastCharge_000017_CH25_structure.csv, Target data shape: (1620,)
# File: processed_FastCharge_000017_CH33_structure.csv, Target data shape: (2171,)
# File: processed_FastCharge_000017_CH41_structure.csv, Target data shape: (2220,)
# File: processed_FastCharge_000017_CH46_structure.csv, Target data shape: (1372,)
# File: processed_FastCharge_000017_CH6_structure.csv, Target data shape: (1624,)
# File: processed_FastCharge_000017_CH9_structure.csv, Target data shape: (1783,)
# File: processed_FastCharge_000050_CH32_structure.csv, Target data shape: (984,)
# File: processed_FastCharge_000050_CH40_structure.csv, Target data shape: (713,)
